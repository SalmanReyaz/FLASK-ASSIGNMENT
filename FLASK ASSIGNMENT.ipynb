# %% [markdown]
# ## `Q1. What is Flask Framework? What are the advantages of Flask Framework?`

# %% [markdown]
# ## `Flask is a micro web framework for building web applications in Python. It is designed to be simple and lightweight, providing the essentials for creating web applications without imposing too many constraints or adding unnecessary features.`
#
#
#
# # Adv. of Flask:---
#
#
# `Lightweight: Flask is a lightweight framework because it is independent of external libraries and it gives a quick start for web development having complex applications.`
#
#
# `Independent: Flask allows full control to the developers for creating web applications. A developer can do the experiment with the libraries and architecture of the framework.`
#
#
# `Flexible and Scalable: Flask supports WSGI templates that help in flexibility and scalability in the web development process.`
#
# `Secure Cookies: Flask supports the feature of secure cookies.`
#
#
# `RESTful APIs: Flask is commonly used to build RESTful APIs due to its simplicity and ease of integration with other libraries and tools commonly used for API development.`

# %% [markdown]
# ## `Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook`.

# %% [markdown]
# ![FLASK%20APPLICATION%20ASSIGNMENT.PNG](attachment:FLASK%20APPLICATION%20ASSIGNMENT.PNG)

# %% [markdown]
# ## `Q3. What is App routing in Flask? Why do we use app routes?`

# %% [markdown]
# `App routing in Flask is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.`
#
# - __@app.route() is decorator Function.__
#
#
#
# `Example: In our application, the URL (“/”) is associated with the root URL. So if our site’s domain was www.example.org and we want to add routing to “www.example.org/hello”, we would use “/hello”.`
#
# `To bind a function to an URL path we use the app.route decorator. In the below example, we have implemented the above routing in the flask.`
# `
#
#
# `In Flask, you use the @app.route() decorator to define routes. The decorator specifies the URL route that should trigger a specific function. This function is often referred to as a "view function" because it handles the logic for generating the content to be displayed to the user.`

# %% [markdown]
# # `Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# __route to show the following details:__
#
# __Company Name: ABC Corporation__
#
# __Location: India__
#
# __Contact Detail: 999-999-9999`__

# %% [markdown]
# ![Welcome%20to%20ABC%20Corporation.PNG](attachment:Welcome%20to%20ABC%20Corporation.PNG)

# %% [markdown]
# ![Flask%20company%20Name.PNG](attachment:Flask%20company%20Name.PNG)

# %% [markdown]
# # `Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.`

# %% [markdown]
# `In Flask, the function used for URL building is url_for(). The url_for() function is used to generate URLs for specific routes within your Flask application. It takes the name of a view function (route function) as its first argument and optionally additional keyword arguments corresponding to the route's variables.`

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def welcome():
    return "Welcome To Pwskills"

if __name__== '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
